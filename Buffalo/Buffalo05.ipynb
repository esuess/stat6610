# %% [markdown]
# ## Python 3 version

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## Scrape one value

# %%
url = "https://www.wunderground.com/history/airport/KBUF/2016/1/1/DailyHistory.html"
page = urlopen(url)

# Get temperature from page
soup = BeautifulSoup(page, "html.parser")
# dayTemp = soup.body.nobr.b.string
dayTemp = soup.find_all(attrs={"class":"wx-value"})[0].string 
dayTemp
# Out:
# '29'

# %% [markdown]
# ## Scrape three values

# %%
import numpy as np

dayTemp = np.empty(3)

print(dayTemp)
# Out:
# [ 0.  0.  0.]

# %%
url = "https://www.wunderground.com/history/airport/KBUF/2016/1/1/DailyHistory.html"
page = urlopen(url)
 
# Get temperature from page
soup = BeautifulSoup(page, "html.parser")
# dayTemp = soup.body.nobr.b.string
dayTemp[0] = soup.find_all(attrs={"class":"wx-value"})[0].string 

url = "https://www.wunderground.com/history/airport/KBUF/2016/1/2/DailyHistory.html"
page = urlopen(url)
 
# Get temperature from page
soup = BeautifulSoup(page, "html.parser")
# dayTemp = soup.body.nobr.b.string
dayTemp[1] = soup.find_all(attrs={"class":"wx-value"})[0].string 

url = "https://www.wunderground.com/history/airport/KBUF/2016/1/3/DailyHistory.html"
page = urlopen(url)
 
# Get temperature from page
soup = BeautifulSoup(page, "html.parser")
# dayTemp = soup.body.nobr.b.string
dayTemp[2] = soup.find_all(attrs={"class":"wx-value"})[0].string 

print(dayTemp)
# Out:
# [ 29.  30.  28.]

# %%
index = 0

for d in range(1, 4):
    url = "https://www.wunderground.com/history/airport/KBUF/2016/1/" + str(d) + "/DailyHistory.html"
    page = urlopen(url)
 
    # Get temperature from page
    soup = BeautifulSoup(page, "html.parser")
    # dayTemp = soup.body.nobr.b.string
    
    index = d-1
    
    dayTemp[index] = soup.find_all(attrs={"class":"wx-value"})[0].string 
    
print(dayTemp)
# Out:
# [ 29.  30.  28.]

# %% [markdown]
# ## Scrape full year of data

# %%
import numpy as np

dayTemp = np.empty(366)

# %%
index = 0
 
# Iterate through months and day
for m in range(1, 13):
    for d in range(1, 32):
 
      # Check if already gone through month
      if (m == 2 and d > 29):
        break
      elif (m in [4, 6, 9, 11] and d > 30):
        break
 
      # Open wunderground.com url
      url = "https://www.wunderground.com/history/airport/KBUF/2016/" + str(m) + "/" + str(d) + "/DailyHistory.html"
      page = urlopen(url)
 
      # Get temperature from page
      soup = BeautifulSoup(page, "html.parser")
      # dayTemp = soup.body.nobr.b.string
      dayTemp[index] = soup.find_all(attrs={"class":"wx-value"})[0].string 
        
      index = index + 1
 
print(dayTemp)
# Out:
# [ 29.  30.  28.  15.  16.  27.  31.  33.  45.  36.  18.  22.  18.  21.  37.
#   36.  21.  15.  16.  22.  21.  17.  17.  21.  36.  40.  33.  33.  27.  34.
#   59.  50.  35.  26.  25.  25.  37.  42.  32.  29.  30.  45.  38.  38.  42.
#   51.  57.  58.  57.  52.  53.  59.  57.  47.  48.  48.  38.  43.  43.  45.
#   52.  50.  45.  50.  53.  54.  56.  60.  49.  50.  53.  61.  67.  61.  51.
#   43.  48.  56.  53.  54.  59.  61.  63.  64.  64.  67.  73.  74.  78.  78.
#   71.  71.  67.  70.  71.  70.  69.  67.  62.  54.  56.  59.  69.  65.  57.
#   60.  70.  73.  72.  74.  72.  75.  68.  68.  68.  67.  73.  78.  77.  70.
#   67.  68.  67.  65.  68.  72.  76.  78.  78.  77.  72.  72.  73.  79.  81.
#   78.  74.  70.  71.  78.  70.  69.  74.  80.  81.  78.  76.  74.  75.  77.
#   76.  75.  74.  74.  74.  74.  78.  80.  78.  73.  73.  79.  81.  83.  82.
#   84.  77.  75.  78.  74.  75.  78.  80.  73.  67.  69.  73.  77.  75.  75.
#   77.  74.  71.  72.  66.  65.  63.  68.  71.  74.  78.  80.  77.  77.  65.
#   64.  68.  64.  60.  65.  72.  72.  71.  69.  69.  70.  66.  56.  55.  61.
#   62.  65.  60.  61.  61.  62.  63.  63.  64.  65.  65.  57.  51.  49.  51.
#   61.  55.  50.  56.  69.  69.  69.  60.  54.  49.  44.  49.  47.  43.  39.
#   42.  41.  55.  48.  41.  54.  61.  51.  45.  52.  48.  50.  49.  44.  44.
#   45.  41.  50.  47.  46.  43.  45.  57.  49.  33.  31.  33.  31.  40.  43.
#   40.  40.  43.  52.  52.  41.  40.  38.  39.  37.  36.  38.  33.  28.  28.
#   26.  34.  30.  21.  13.  16.  27.  25.  17.  27.  33.  34.  35.  38.  32.
#   42.  39.  30.  34.  30.  34.]

# %% [markdown]
# ## Read data and plot

# %%
import pandas as pd

buffalo = pd.DataFrame(dayTemp, columns=['Temp'])

dates = pd.date_range('1/1/2016', periods=366)

buffalo = buffalo.set_index(dates)

print(buffalo.head(5))
print(buffalo.tail(5))
# Out:
#             Temp
# 2016-01-01    29
# 2016-01-02    30
# 2016-01-03    28
# 2016-01-04    15
# 2016-01-05    16
#             Temp
# 2016-12-27    39
# 2016-12-28    30
# 2016-12-29    34
# 2016-12-30    30
# 2016-12-31    34

# %%
import matplotlib.pyplot as plt

# %%
# plot
plt.plot(buffalo.Temp)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
import seaborn as sns

# %%
sns.tsplot(data = buffalo.Temp)

plt.show()

# %%
from ggplot import *

# %%
buffalo['Date'] = buffalo.index

ggplot(aes(x='Date', y='Temp'), data=buffalo) + \
    geom_line(color='blue')
# Out:
# <ggplot: (8729932219845)>
